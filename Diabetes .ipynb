# %% [markdown]
# ## project (Diabetes)

# %% [markdown]
# <a id='content'></a>
#
# ## content
# <ul>
#
# <li><a href="#intro">Data Describtion</a></li>
# <li><a href="#business plan">business plan  </a></li>
#
# <li><a href="#load data "> load data </a></li>
#
# <li><a href="#data assessing"> Data assessing </a></li>
#
# <li><a href="#data clean">Data cleaning & processing   </a></li>
#
# <li><a href="#data visualization">Data visualization  </a></li>
#
# <li><a href="#model"> Model</a></li>
#
# <li><a href="#using Model"> using model</a></li>
#
#
# </ul>

# %% [markdown]
# <a id='intro'></a>
#
#
# ### Data Describtion
#
#
#
# <a href="#content">back to content </a>

# %% [markdown]
#     Diabetes:: is a disease that occurs when your blood glucose, also called blood sugar, is too high. Blood glucose is your main source of energy and comes from the food you eat. Insulin, a hormone made by the pancreas, helps glucose from food get into your cells to be used for energy
#             __________________________________________
#
#
#
# Describtion  of  columns  in Diabetes file:
#
#
#
#         __________________________________________
#
# Gender :
#
#         M : male
#         F : Female
#         __________________________________________
# Urea :
#
#         Women < 50 years  :2.6 – 6.7 mmol/L,
#         Women > 50 years  :3.5 – 7.2 mmol/L ,
#         Men < 50 years    :3.2 – 7.3 mmol/L
#         Men > 50 years	  :3.0 – 9.2 mmol/L
#         __________________________________________
#
# cr:
#
#         Normal Serum creatinine  for healthy women is 53 to 97.2mL/min.
#         and 61.9 to 114.9  mL/min. in males
#         (normal levels may vary slightly between labs).
#         __________________________________________
#
#
# HbA1c :
#
#         Normal : Below 5.7%
#         Prediabetes:5.7% to 6.4%
#         Diabetes :6.5% or above
#         __________________________________________
#
# chol :
#
#         less than 5.18 m mol/l : desirable,
#         5.18-6.18  : borderline high ,
#         6.22 and above : high
#         __________________________________________
#
#
# Tg :
#
#         less than 1.7m mol/l :desirable ,
#         1.7-2.2  : borderline high  ,
#         2.3-5.6 :  high,
#         5.6 and above: very high
#         __________________________________________
#
# HDL:
#
#         less than 1 : a major risk factor for heart disease
#         1-1.3: the higher , the better
#         1.55 and above : considered protective against heart disease
#
#         __________________________________________
# LDL:
#
#         less than 2.59m mol/l :desirable ,
#         2.59-3.34  : near desirable ,
#         3.37-4.12 : borderline high,
#         4.15-4.90 : high ,
#         4.90 and above: very high
#
#
# VLDL:	Normal VLDL levels are from 2 to 30 mg/dL (0.1 to 1.7 mmol/l)
#
#         __________________________________________
#
# Bmi :
#
#         Below 18.5 :	Underweight,
#         18.5—24.9:	Healthy,
#         25.0—29.9	:Overweight,
#         30.0 and Above:	Obese
#         __________________________________________
#
# Class:
#
#         N : NO   .....( Not have diabetes )
#
#         P : prediabetes
#
#         Y : Yes ( have diabetes )

# %% [markdown]
# <a id='business plan'></a>
#
# #### business plan:
#
#
#
#     _______________
#
# <ul>
# <li><a href="#Q1">Q1: what is the percentage of male and female in this data?and the percentage of disease ?
# </a></li>
# <li><a href="#Q2">Q2: What is the range of age the disease is common?
#   </a></li>
#
# <li><a href="#Q3 "> Q3 : what is the features are related with the class ? and how we can classification the disease?
#  </a></li>
#
# </ul>
#
#
# <a href="#content">back to content </a>

# %%
# import libraries
import pandas as pd 
import numpy  as np
import matplotlib.pyplot as plt 
import plotly.express as px
import graphviz
import seaborn as sns
sns.set_style("darkgrid")

from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score,f1_score
from sklearn import tree
import joblib

# %% [markdown]
# <a id='load data'></a>
# ## load Data
#
# <a href="#content">back to content </a>

# %%
# load data 
df=pd.read_csv('Diabetes.csv')
df.head(100)
# Out:
#      ID  No_Pation Gender  AGE  Urea   Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0   502      17975      F   50   4.7   46    4.9   4.2  0.9  2.4  1.4   0.5
# 1   735      34221      M   26   4.5   62    4.9   3.7  1.4  1.1  2.1   0.6
# 2   420      47975      F   50   4.7   46    4.9   4.2  0.9  2.4  1.4   0.5
# 3   680      87656      F   50   4.7   46    4.9   4.2  0.9  2.4  1.4   0.5
# 4   504      34223      M   33   7.1   46    4.9   4.9  1.0  0.8  2.0   0.4
# 5   634      34224      F   45   2.3   24    4.0   2.9  1.0  1.0  1.5   0.4
# 6   721      34225      F   50   2.0   50    4.0   3.6  1.3  0.9  2.1   0.6
# 7   421      34227      M   48   4.7   47    4.0   2.9  0.8  0.9  1.6   0.4
# 8   670      34229      M   43   2.6   67    4.0   3.8  0.9  2.4  3.7   1.0
# 9   759      34230      F   32   3.6   28    4.0   3.8  2.0  2.4  3.8   1.0
# 10  636      34231      F   31   4.4   55    4.2   3.6  0.7  1.7  1.6   0.3
# ...

# %%
# Drop 2 columns are not effect in the data 
df=df.drop(['ID','No_Pation'],axis=1)

# %% [markdown]
# <a id='data assessing'></a>
# ## Data Assessing
#
#
# <a href="#content">back to content </a>

# %%
# show the type of data & if  the data have missing values 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  1000 non-null   object
#  1   AGE     1000 non-null   int64
#  2   Urea    1000 non-null   float64
#  3   Cr      1000 non-null   int64
#  4   HbA1c   1000 non-null   float64
#  5   Chol    1000 non-null   float64
#  6   TG      1000 non-null   float64
#  7   HDL     1000 non-null   float64
#  8   LDL     1000 non-null   float64
#  9   VLDL    1000 non-null   float64
#  10  BMI     1000 non-null   float64
#  11  CLASS   1000 non-null   object
# dtypes: float64(8), int64(2), object(2)
# memory usage: 93.9+ KB

# %%
#missing 
df.isna().sum()
# Out:
# Gender    0
# AGE       0
# Urea      0
# Cr        0
# HbA1c     0
# Chol      0
# TG        0
# HDL       0
# LDL       0
# VLDL      0
# BMI       0
# CLASS     0
# dtype: int64

# %% [markdown]
# ### note:
#
# > Data don't have any missing data it is good

# %%
#check Gender value
df.Gender.value_counts()
# Out:
# M    565
# F    434
# f      1
# Name: Gender, dtype: int64

# %% [markdown]
# ### note:
#
# > Data have a mistake in letter f  we need write it capital letter

# %%
# check Age 
df.AGE.value_counts().sort_values(ascending=False)
# Out:
# 55    181
# 60     88
# 54     84
# 51     51
# 61     49
# 56     48
# 52     44
# 50     43
# 59     32
# 57     31
# 58     30
# 63     29
# 53     25
# 30     20
# 49     19
# 33     16
# 45     16
# 40     13
# 44     13
# 66     11
# 35     11
# 47     10
# 42     10
# 48     10
# 31      9
# 39      9
# 68      8
# 73      8
# 62      8
# 43      8
# 64      7
# 67      6
# 38      6
# 69      6
# 41      5
# 34      5
# 36      4
# 76      4
# 77      4
# 46      3
# 28      3
# 70      2
# 65      2
# 26      2
# 75      2
# 79      1
# 32      1
# 71      1
# 25      1
# 20      1
# Name: AGE, dtype: int64

# %% [markdown]
# ### note:
#
# >Why the high numbers at 55 years ??

# %%
df.HbA1c.value_counts().sort_values(ascending=False)
# Out:
# 8.00     34
# 9.00     32
# 7.00     32
# 4.00     30
# 6.80     30
# 6.00     25
# 10.20    24
# 7.20     21
# 5.00     20
# 6.50     19
# 7.70     19
# 8.50     19
# 6.90     16
# 5.40     16
# 9.70     16
# 8.10     16
# 7.60     16
# 11.00    15
# 9.10     15
# 6.70     15
# 7.30     15
# 9.30     14
# 7.90     13
# 10.90    13
# 8.90     13
# 10.00    12
# 8.80     12
# 10.50    12
# 10.70    12
# 11.20    11
# 9.40     11
# 7.80     11
# 9.90     11
# 11.80    11
# 6.20     10
# 7.10     10
# 7.40     10
# 10.80    10
# 8.20     10
# 6.40     10
# 5.80     10
# 12.30    10
# 10.60    10
# 7.50     10
# 4.30     10
# 5.70     10
# 5.90     10
# 10.40    10
# 4.90     10
# 6.10      9
# 5.10      9
# 5.50      9
# 10.30     9
# 9.20      9
# 4.10      8
# 13.70     8
# 4.50      7
# 9.80      7
# 12.20     7
# 8.70      7
# 10.10     7
# 12.00     6
# 8.30      6
# 12.40     6
# 6.30      6
# 9.60      6
# 11.30     6
# 9.50      6
# 11.90     6
# 11.50     6
# 8.60      6
# ...

# %%
df.Chol.value_counts().sort_values(ascending=False)
# Out:
# 4.40     55
# 4.90     46
# 4.80     40
# 4.00     38
# 5.30     38
# 4.20     37
# 4.10     36
# 5.20     33
# 3.60     33
# 4.70     30
# 5.40     29
# 4.50     28
# 4.60     27
# 5.60     25
# 5.50     24
# 5.90     24
# 5.00     23
# 3.40     22
# 5.80     22
# 4.30     22
# 3.80     22
# 3.70     22
# 5.10     21
# 3.90     20
# 5.70     18
# 6.20     17
# 6.10     16
# 3.50     16
# 6.00     15
# 6.30     15
# 3.20     14
# 7.20     10
# 6.50     10
# 3.10      9
# 3.00      9
# 6.80      9
# 6.70      9
# 6.60      8
# 2.40      6
# 7.30      6
# 6.40      6
# 2.00      6
# 3.30      6
# 7.00      5
# 2.90      5
# 2.80      5
# 2.50      4
# 6.90      4
# 2.70      4
# 9.50      4
# 7.10      4
# 2.60      4
# 2.30      3
# 7.70      3
# 9.80      2
# 7.40      2
# 2.10      2
# 0.60      2
# 7.90      2
# 8.80      2
# 9.70      2
# 7.50      2
# 8.00      2
# 8.50      2
# 9.30      1
# 6.12      1
# 1.20      1
# 9.90      1
# 0.00      1
# 10.30     1
# 8.10      1
# ...

# %%
df.TG.value_counts().sort_values(ascending=False)
# Out:
# 2.10     65
# 2.00     61
# 1.30     52
# 1.50     51
# 1.70     44
# 1.90     42
# 1.80     38
# 1.60     35
# 2.20     34
# 1.20     33
# 1.10     31
# 1.00     29
# 2.30     27
# 0.70     25
# 3.30     23
# 1.40     23
# 2.60     21
# 3.00     20
# 2.40     20
# 2.70     20
# 2.50     20
# 2.90     19
# 5.10     18
# 0.80     17
# 3.70     15
# 0.90     15
# 3.80     14
# 0.60     14
# 3.10     14
# 3.20     13
# 3.50     12
# 4.50     12
# 3.90      9
# 3.40      9
# 2.80      8
# 5.30      7
# 3.60      6
# 4.00      6
# 4.40      5
# 4.90      5
# 4.20      5
# 4.30      5
# 4.10      5
# 2.03      4
# 4.60      4
# 4.70      3
# 7.00      3
# 5.90      3
# 1.19      3
# 5.50      3
# 6.80      3
# 1.91      2
# 0.30      2
# 7.20      2
# 5.80      2
# 7.70      2
# 4.80      2
# 5.00      2
# 6.00      2
# 6.70      2
# 13.80     1
# 5.70      1
# 11.60     1
# 6.30      1
# 8.70      1
# 12.70     1
# 5.40      1
# 0.50      1
# 8.50      1
# Name: TG, dtype: int64

# %%
df.HDL.value_counts().sort_values(ascending=False)
# Out:
# 1.10    147
# 0.90    141
# 1.00    135
# 0.80     84
# 1.30     80
# 1.20     71
# 0.70     57
# 1.40     54
# 1.60     40
# 1.80     31
# 0.60     24
# 1.70     22
# 1.50     20
# 1.90     13
# 2.40      8
# 0.50      7
# 2.30      7
# 0.40      7
# 2.00      4
# 2.50      4
# 0.75      3
# 3.10      3
# 1.35      3
# 2.10      3
# 3.20      3
# 6.60      2
# 1.95      2
# 1.03      2
# 3.60      2
# 1.08      2
# 1.45      2
# 2.80      1
# 9.00      1
# 3.80      1
# 3.40      1
# 6.30      1
# 0.20      1
# 0.95      1
# 1.85      1
# 2.20      1
# 1.73      1
# 1.75      1
# 2.60      1
# 4.00      1
# 9.90      1
# 3.90      1
# 5.00      1
# 1.05      1
# Name: HDL, dtype: int64

# %%
df.LDL.value_counts().sort_values(ascending=False)
# Out:
# 2.50    87
# 2.00    55
# 1.70    40
# 3.10    37
# 3.00    37
# 1.40    37
# 2.60    35
# 3.50    32
# 3.60    32
# 1.30    29
# 2.70    28
# 1.80    28
# 4.10    28
# 2.10    27
# 3.20    27
# 2.40    26
# 2.30    26
# 3.30    25
# 1.60    24
# 2.80    23
# 3.70    22
# 0.90    22
# 1.90    21
# 1.50    21
# 2.90    20
# 2.20    20
# 3.90    17
# 1.20    17
# 3.80    16
# 3.40    13
# 4.00    12
# 1.10    11
# 1.00     9
# 4.30     9
# 4.20     8
# 0.80     7
# 5.00     7
# 4.90     5
# 4.80     4
# 5.50     4
# 1.35     4
# 4.40     4
# 4.60     4
# 0.95     4
# 0.60     3
# 0.75     3
# 5.60     3
# 4.70     3
# 1.45     2
# 0.70     2
# 0.50     2
# 1.95     2
# 4.50     2
# 9.90     2
# 7.90     2
# 7.00     1
# 2.04     1
# 6.40     1
# 5.30     1
# 1.04     1
# 0.30     1
# 7.50     1
# 0.96     1
# 5.90     1
# 5.10     1
# Name: LDL, dtype: int64

# %%
df.VLDL.value_counts().sort_values(ascending=False)
# Out:
# 0.9     132
# 0.7      94
# 0.6      80
# 0.8      76
# 1.0      71
# 1.5      63
# 0.5      55
# 1.1      54
# 1.3      44
# 0.4      37
# 2.0      36
# 1.4      34
# 1.2      33
# 0.3      26
# 1.7      26
# 1.6      21
# 1.8      11
# 14.0      8
# 1.9       8
# 12.7      6
# 2.2       5
# 3.1       5
# 0.2       5
# 8.1       5
# 2.4       4
# 13.1      4
# 10.4      4
# 2.1       4
# 15.4      3
# 2.6       3
# 0.1       2
# 3.0       2
# 11.3      2
# 3.5       2
# 9.5       2
# 14.5      2
# 10.0      2
# 7.2       2
# 12.2      2
# 2.8       2
# 22.2      2
# 31.8      2
# 2.5       2
# 6.3       1
# 24.5      1
# 18.1      1
# 33.6      1
# 9.0       1
# 5.8       1
# 19.5      1
# 7.0       1
# 5.0       1
# 27.2      1
# 35.0      1
# 3.4       1
# 16.3      1
# 5.2       1
# 4.1       1
# 31.0      1
# 22.7      1
# Name: VLDL, dtype: int64

# %%
df.CLASS.value_counts()
# Out:
# Y     840
# N     102
# P      53
# Y       4
# N       1
# Name: CLASS, dtype: int64

# %%
df.CLASS.unique()
# Out:
# array(['N', 'N ', 'P', 'Y', 'Y '], dtype=object)

# %% [markdown]
# > Data have a mistake here  in Y & N

# %% [markdown]
# <a id='data clean'></a>
# ## Data cleaning & processing
#
#
# <a href="#content">back to content </a>

# %% [markdown]
# #### Define :  f small in gender (convert it to F capital )

# %%
# code: 
df['Gender']=df.Gender.replace('f',"F")

# %%
# test 
df.Gender.value_counts()
# Out:
# M    565
# F    435
# Name: Gender, dtype: int64

# %% [markdown]
# ##### Define:  Y&N in class

# %%
# code :
df['CLASS']=df.CLASS.replace('Y ','Y')
df['CLASS']=df.CLASS.replace('N ','N')

# %%
# test:
df.CLASS.value_counts()
# Out:
# Y    844
# N    103
# P     53
# Name: CLASS, dtype: int64

# %% [markdown]
# <a id='data visualization'></a>
#
# ## Data Visualization
#
#
# <a href="#content">back to content </a>

# %% [markdown]
# <a id='Q1'></a>
# ### Q1: what is the percentage of male and female in this data?and the percentage of disease ?

# %%
# count of male vs female

plt.figure(figsize=(7,7))
ax=sns.countplot(df.Gender ,palette="spring").get_figure()
plt.title(' count of male vs female ',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel("Gender",fontsize=15)
plt.ylabel("count",fontsize=15)
plt.text(-.1, 250,'435', fontsize=15) 
plt.text(0.9, 350,'565', fontsize=15) 
plt.show()
ax.savefig('count_male_female.png',bbox_inches='tight')

# %% [markdown]
# ### conclusion :
#
# >The count of males =565, and females= 435, the total is 1000.
#
#         It is mean the count of males is larger than females

# %%
#create data to count gender in each class
groupby_class=pd.DataFrame(df.groupby('CLASS')['Gender'].value_counts())
groupby_class.rename(columns={"Gender": "count"},inplace=True)
groupby_class.reset_index()
# Out:
#   CLASS Gender  count
# 0     N      F     64
# 1     N      M     39
# 2     P      M     36
# 3     P      F     17
# 4     Y      M    490
# 5     Y      F    354

# %%
#count male vs female in every class
plt.figure(figsize=(10,8))
g=sns.countplot(df.Gender , hue='CLASS', data= df, palette="twilight")

plt.title(' count of male vs female in every class ',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel("Gender",fontsize=15)

plt.ylabel("count",fontsize=15)

g.text(-.316, 30,'64', fontsize=15) 
g.text(-.1, 25,'17', fontsize=15) 
g.text(0.19, 320,'354', fontsize=15) 
g.text(0.68, 20,'39', fontsize=15) 
g.text(0.95, 38,'36', fontsize=15) 
g.text(1.2, 460,'490', fontsize=15)
plt.show()

# %%
#count male vs female in every class
plt.figure(figsize=(20,10))

labels = ["f (N)","m (N)","m (P)","f (P)",'m (Y)',"f (Y)"]
sizes = groupby_class["count"].values
explode = (0, 0, 0, 0,0,0)  
colors = ['tab:blue', 'tab:cyan', 'tab:gray', 'tab:orange', 'tab:red']

plt.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',colors=colors,textprops={'fontsize': 14})

plt.title( "count of male vs female in every class",fontsize=25)
plt.legend(loc='best', bbox_to_anchor=(.7, 0.5, 0.5, 0.5),fontsize=13)
plt.show()

# %% [markdown]
# ### conculsion :
# >The males   who have diabetes are  490,   prediabetes  are 36  and  39  don't have diabetes  from 565
#
# >The females who have diabetes are 354, prediabetes is 16, and 64 do not have diabetes from 435.

# %%
# proportion of male and female  of gender & total 

groupby_class['percentage_of_gender']=[14.71,6.90,6.37,3.90,86.73,81.38]
groupby_class['percentage_of_total']= (groupby_class['count']/groupby_class['count'].sum() )*100
groupby_class=groupby_class.reset_index()
groupby_class
# Out:
#    index CLASS Gender  count  percentage_of_gender  percentage_of_total
# 0      0     N      F     64                 14.71                  6.4
# 1      1     N      M     39                  6.90                  3.9
# 2      2     P      M     36                  6.37                  3.6
# 3      3     P      F     17                  3.90                  1.7
# 4      4     Y      M    490                 86.73                 49.0
# 5      5     Y      F    354                 81.38                 35.4

# %%
## proportion of male and female  of gender 
plt.figure(figsize=(20,10))

labels = ["f (N)","m (N)","m (P)","f (P)",'m (Y)',"f (Y)"]
sizes = groupby_class["percentage_of_gender"].values
explode = (0, 0, 0, 0,0,0)  
colors = ['tab:blue', 'tab:cyan', 'tab:gray', 'tab:orange', 'tab:red']

plt.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',colors=colors,textprops={'fontsize': 14})

plt.title( "proportion of male and female  of gender ",fontsize=25)
plt.legend(loc='best', bbox_to_anchor=(.7, 0.5, 0.5, 0.5),fontsize=13)
plt.show()

# %%
## proportion of male and female  of total 
plt.figure(figsize=(20,10))

labels = ["f (N)","m (N)","m (P)","f (P)",'m (Y)',"f (Y)"]
sizes = groupby_class["percentage_of_total"].values
explode = (0, 0, 0, 0,0,0)  
colors = ['tab:blue', 'tab:cyan', 'tab:gray', 'tab:orange', 'tab:red']

plt.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',colors=colors,textprops={'fontsize': 14})

plt.title( "proportion of male and female  of total ",fontsize=25)
plt.legend(loc='best', bbox_to_anchor=(.7, 0.5, 0.5, 0.5),fontsize=13)
plt.show()

# %%
# proportion of male and female  of gender  

sns.catplot(x="Gender", y="percentage_of_gender", hue="percentage_of_gender",
                col='CLASS',
                data=groupby_class, kind="bar" );

# %%
# proportion of male and female  of  total 
sns.catplot(x="Gender", y="percentage_of_total", hue="percentage_of_total",
                col='CLASS',
                data=groupby_class, kind="bar" );

# %% [markdown]
# ### conculsion:
# > The proportion of  males who have diabetes is 86.37 % from males, and 49% from total  ,  and prediabetes is 6.37% from males & 3.6% from total
#
# > while the proportion of females who have diabetes is 81.38 from females and 35.4 from total  and prediabetes is 3.9 from females & 1.7 from total

# %% [markdown]
# <a id='Q2'></a>
#
# ### Q2: What is the range of age the disease is common? (distribution)

# %%
# distribution  for age in each class
plt.figure(figsize=(10,6.5))
sns.stripplot(x="AGE", y="CLASS", hue="Gender",palette="dark", dodge=True,data=df);
plt.title(' distribution  for age in each class',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel("Age",fontsize=15)
plt.ylabel("Class ",fontsize=15)
plt.axvline(50, 0,.3,color="black")
plt.axvline(65, 0,.3,color="black")

plt.show()

# %%
# distribution  for age in each class
plt.figure(figsize=(10,6.5))
sns.boxplot(x="AGE", y="CLASS", hue="Gender",palette="dark", dodge=True,data=df);
plt.title(' distribution  for age in each class',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel("Age",fontsize=15)
plt.ylabel("Class ",fontsize=15)

plt.show()

# %% [markdown]
# ### conclusion:
#
# > We see an increased risk of diabetes between age (50-65)

# %% [markdown]
# <a id='Q3'></a>
#
# ### Q3 : what is the features are related with the class ?  and how we can classification the disease ?

# %%
# copy data  
df_copy=df.copy()
# convert categorical to numerical 
enc = OrdinalEncoder()
df_copy[['Gender','CLASS']]=enc.fit_transform(df_copy[['Gender','CLASS']])

# %%
#correlation between all feature & class 
plt.figure(figsize=(15,8))

sns.heatmap(df_copy.corr(), annot=True, fmt='0.2f');


plt.title('correlation between all feature & class',fontsize=15)

plt.show()

# %% [markdown]
# ### conclusion:
#
# > the correlation between ['Urea','Cr', 'HDL', 'LDL']  and class is very low

# %%
# drop the features have low correlation with class
df_copy=df_copy.drop(['Urea','Cr', 'HDL', 'LDL'],axis=1)
df_copy.head()
# Out:
#    Gender  AGE  HbA1c  Chol   TG  VLDL   BMI  CLASS
# 0     0.0   50    4.9   4.2  0.9   0.5  24.0    0.0
# 1     1.0   26    4.9   3.7  1.4   0.6  23.0    0.0
# 2     0.0   50    4.9   4.2  0.9   0.5  24.0    0.0
# 3     0.0   50    4.9   4.2  0.9   0.5  24.0    0.0
# 4     1.0   33    4.9   4.9  1.0   0.4  21.0    0.0

# %%
# check the  value after convert 
df_copy.CLASS.value_counts(),df_copy.Gender.value_counts()
# Out:
# (2.0    844
#  0.0    103
#  1.0     53
#  Name: CLASS, dtype: int64,
#  1.0    565
#  0.0    435
#  Name: Gender, dtype: int64)

# %% [markdown]
# >Class
#
#              0 = N
#
#              1 = p
#
#              2 = Y
#
# > Gender
#
#              0 = F
#
#              1 = M

# %%
# show data class Y (2)
#pd.set_option('display.max_rows', 1000)
df_copy.query('CLASS==2.0 ')
# Out:
#      Gender  AGE  HbA1c  Chol   TG  VLDL   BMI  CLASS
# 156     1.0   31   12.3   4.1  2.2  15.4  37.2    2.0
# 157     1.0   30    6.7   4.1  1.1   8.1  27.4    2.0
# 158     1.0   45   10.2   4.8  1.3   9.5  34.3    2.0
# 159     1.0   45   10.2   4.8  1.3   9.5  34.3    2.0
# 160     1.0   45   11.2   3.9  1.5  10.4  29.5    2.0
# ..      ...  ...    ...   ...  ...   ...   ...    ...
# 995     1.0   71    7.0   7.5  1.7   0.6  30.0    2.0
# 996     1.0   31   12.3   4.1  2.2  15.4  37.2    2.0
# 997     1.0   30    6.7   4.1  1.1   8.1  27.4    2.0
# 998     1.0   38    6.7   5.3  2.0  14.0  40.5    2.0
# 999     1.0   54    6.9   3.8  1.7   0.7  33.0    2.0
#
# [844 rows x 8 columns]

# %%
### distribution  for Hba1c

plt.figure(figsize=(8,6))
sns.stripplot(x="HbA1c", y="CLASS", hue="Gender",palette="dark", dodge=True,data=df);
plt.title('distribution  for Hba1c' ,fontsize=15)
plt.xlabel("HbA1c",fontsize=15)
plt.ylabel("Class ",fontsize=15)
plt.axvline(6.5,0,0.3,color="red")
plt.show()

# %% [markdown]
# ### conclusion:
#
#         Normal : Below 5.7%
#         Prediabetes:5.7% to 6.4%
#         Diabetes :6.5% or above
# but we found patients have diabetes and the HbA1c less than 6.5 !! why?

# %%
##create new data to find the reason why some patients have the disease although Hba1c <6.5
df_HbA1c=df.query('HbA1c < 6.5 & CLASS=="Y"')
df_HbA1c.shape
# Out:
# (83, 12)

# %% [markdown]
# > Data have 83 case it is  not normal in HbA1c   let check  this

# %%
df_HbA1c.head()
# Out:
#     Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL   BMI CLASS
# 169      M   45   3.6  80    5.0   6.1  3.7  0.7  3.9   1.7  22.0     Y
# 174      F   46   3.0  59    5.1   5.7  3.8  1.3  2.8   1.7  24.0     Y
# 175      M   45   2.3  42    5.1   4.4  1.5  1.0  2.8   0.5  25.0     Y
# 178      M   43   5.4  62    4.1   5.9  2.0  1.1  3.9   0.9  21.0     Y
# 179      M   49   3.9  65    5.2   5.1  1.7  3.9  0.8   1.6  24.0     Y

# %%
# relation   between the Hba1c & age  & class
plt.figure(figsize=(20,10))
sns.stripplot(x="HbA1c", y="AGE", hue="CLASS",palette="husl", dodge=True,data=df)
plt.xticks(rotation=90)
plt.title("relation   between the Hba1c & age  & class ",fontsize=15)
plt.xlabel("Hba1c",fontsize=15)
plt.ylabel("Age",fontsize=15)
plt.axvline(28,0,80,color="black")
plt.axvline(20,0,0.5,color="black")

plt.show()

# %% [markdown]
# ### conclusion:
#
#
#     HbA1C >6.5  .... class be Y
#
#     age 51-53 & HbA1C 6 or above .....class be Y
#
#     age >53 & HbA1C 2 or above  the most ..... class be Y
#
#     age 30-50 HbA1C 5.7-6.4........ classs be P
#
#     age 20-80 HbA1C 3-5.6 ...... class can be Y or N  what the feature related with this is case ?

# %%
## relation   between the BMi  & age  & class

plt.figure(figsize=(20,10))
sns.stripplot(x="BMI", y="AGE", hue="CLASS",palette="husl", dodge=True,data=df)
plt.xticks(rotation=90,fontsize=10)
plt.yticks(fontsize=10)
plt.title("relation   between the BMi & age  & class ",fontsize=15)
plt.xlabel("BMI",fontsize=15)
plt.ylabel("Age",fontsize=15)
plt.axvline(38,0,.52,color="black")
plt.axvline(14,5,0.5,color="black")
plt.axhline(50,.21,.6,color="red")
plt.show()

# %% [markdown]
# ### conclusion:
#
#      when age >50 & bmi >= 26 ...... class be Y
#
#     20 < age <30  & bmi >=24 ...... class be Y
#
#     age 20-50 & bmi >=33 ...... class be Y
#
#     age 20-50 or above  bmi 19-24 ...... class can be Y or N

# %%
# 3d plot 
fig = px.scatter_3d(df,x='BMI', y='AGE', z='HbA1c',color_discrete_map={'Y': 'red', 'N': 'yellow','P':'green'},color="CLASS")

fig.show()
# Out:
# <div>                            <div id="3bc66715-5b59-4d3a-a8ff-5cf124c24bc5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3bc66715-5b59-4d3a-a8ff-5cf124c24bc5")) {                    Plotly.newPlot(                        "3bc66715-5b59-4d3a-a8ff-5cf124c24bc5",                        [{"hovertemplate":"CLASS=N<br>BMI=%{x}<br>AGE=%{y}<br>HbA1c=%{z}<extra></extra>","legendgroup":"N","marker":{"color":"yellow","symbol":"circle"},"mode":"markers","name":"N","scene":"scene","showlegend":true,"type":"scatter3d","x":[24.0,23.0,24.0,24.0,21.0,21.0,24.0,24.0,21.0,24.0,23.0,21.0,22.0,23.0,24.0,21.0,21.0,22.0,24.0,23.0,24.0,24.0,24.0,23.0,21.0,22.0,19.0,22.0,22.0,22.0,23.0,24.0,22.0,24.0,23.0,22.0,21.0,21.0,24.0,23.0,24.0,21.0,22.0,21.0,24.0,21.0,23.0,24
# ...

# %%
# create new data to discoverd  the cases AGE<50 & HbA1c<5.7  
df_age = df.query('AGE<50 & HbA1c<5.7 ')
df_age.head()
# Out:
#   Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL   BMI CLASS
# 1      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6  23.0     N
# 4      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4  21.0     N
# 5      F   45   2.3  24    4.0   2.9  1.0  1.0  1.5   0.4  21.0     N
# 7      M   48   4.7  47    4.0   2.9  0.8  0.9  1.6   0.4  24.0     N
# 8      M   43   2.6  67    4.0   3.8  0.9  2.4  3.7   1.0  21.0     N

# %%
#  distribution bmi  when AGE<50 & HbA1c<5.7
plt.figure(figsize=(20,10))
sns.stripplot(x="HbA1c", y="BMI", hue="CLASS",palette="husl", dodge=True,data=df_age)

plt.xticks(rotation=90,fontsize=15)
plt.yticks(fontsize=15)
plt.title(" distribution bmi  when AGE<50 & HbA1c<5.7 ",fontsize=20)
plt.xlabel("HbA1c",fontsize=15)
plt.ylabel("BMI",fontsize=15)
plt.axhline(24.9,color="red");

# %% [markdown]
# ### conclusion:
#
# when HbA1c <5.7 & bmi =25 ...... class  be y

# %%
# create new data to discoverd  the cases AGE<50 & HbA1c<5.7 &BMI!=25  

df_age2 = df_copy.query('AGE<50 & HbA1c<5.7 &BMI!=25 ')
df_age2.head()
# Out:
#    Gender  AGE  HbA1c  Chol   TG  VLDL   BMI  CLASS
# 1     1.0   26    4.9   3.7  1.4   0.6  23.0    0.0
# 4     1.0   33    4.9   4.9  1.0   0.4  21.0    0.0
# 5     0.0   45    4.0   2.9  1.0   0.4  21.0    0.0
# 7     1.0   48    4.0   2.9  0.8   0.4  24.0    0.0
# 8     1.0   43    4.0   3.8  0.9   1.0  21.0    0.0

# %%
# discover the feature is most related when AGE<50 & HbA1c<5.7 &BMI!=25
g=sns.pairplot(df_age2, hue='CLASS', );
g.fig.suptitle("discover the feature is most related when AGE<50 & HbA1c<5.7 &BMI!=25", y=1.08,fontsize=25);

# %% [markdown]
# >the feature most related   bmi &chol

# %%
# plotting 3d  between chol &bmi& HbA1c
fig = px.scatter_3d(df_age2,x='Chol', y='BMI', z='HbA1c',color_discrete_map={'Y': 'red', 'N': 'yellow','P':'green'},color="CLASS")

fig.show()
# Out:
# <div>                            <div id="1fe3080c-5e66-4563-aa26-95f9d0a452da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1fe3080c-5e66-4563-aa26-95f9d0a452da")) {                    Plotly.newPlot(                        "1fe3080c-5e66-4563-aa26-95f9d0a452da",                        [{"hovertemplate":"CLASS=N<br>Chol=%{x}<br>BMI=%{y}<br>HbA1c=%{z}<extra></extra>","legendgroup":"N","marker":{"color":"yellow","symbol":"circle"},"mode":"markers","name":"N","scene":"scene","showlegend":true,"type":"scatter3d","x":[3.7,4.9,2.9,2.9,3.8,3.8,3.6,4.0,4.9,4.2,4.9,5.0,4.4,0.5,6.2,4.2,4.6,4.9,5.5,2.8,3.7,5.6,3.2,4.6,3.6,6.2,6.5,4.0,3.0,3.7,3.7,4.4,3.8,9.5,3.7,4.7,4.2,5.2,4.3,4.7,9.5,4.7,4.9,4.3,4.8,4.1,3.1,4.2,5.2,3.6,4.0,4.3,4.9,3.8,4.8,4.7,3.0,4.4,7.6,
# ...

# %% [markdown]
# ### conclusion:
#
#  when age <50 & HbA1c<5.7 &bmi<25  & chol >=5  ......class be Y

# %% [markdown]
# <a id='model'></a>
#
# ## Model
#
#
# <a href="#content">back to content </a>

# %%
# prepareing the train & test columns 
X=df_copy.drop(['CLASS','Gender','VLDL','TG'],axis=1)
y=df_copy.CLASS

# %%
X.head()
# Out:
#    AGE  HbA1c  Chol   BMI
# 0   50    4.9   4.2  24.0
# 1   26    4.9   3.7  23.0
# 2   50    4.9   4.2  24.0
# 3   50    4.9   4.2  24.0
# 4   33    4.9   4.9  21.0

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.20, random_state=32)

# %%
# after analysis I decided to use the model related to decision tree

models = {
    "DT": DecisionTreeClassifier(),
    "RF": RandomForestClassifier(),
    "XGB": XGBClassifier(),
}

# %%
for name, model in models.items():
    print(f'Training Model {name} \n--------------')
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    print(f'Training Accuracy: {accuracy_score(y_train, model.predict(x_train))}')
    print(f'Testing Accuracy: {accuracy_score(y_test, y_pred)}')
    print(f'Testing Confusion Matrix: \n{confusion_matrix(y_test, y_pred)}')
    print(f'Testing Recall: {recall_score(y_test, y_pred,average="macro")}')    
    print(f'Testing Precesion: {precision_score(y_test, y_pred,average="macro")}')
    print(f'Testing F1 score :{f1_score(y_test, y_pred, average="macro")}')


    print('-'*30)
# Out:
# Training Model DT
# --------------
# Training Accuracy: 1.0
# Testing Accuracy: 0.995
# Testing Confusion Matrix:
# [[ 27   0   0]
#  [  0   9   0]
#  [  1   0 163]]
# Testing Recall: 0.9979674796747968
# Testing Precesion: 0.9880952380952381
# Testing F1 score :0.9929200259475489
# ------------------------------
# Training Model RF
# --------------
# Training Accuracy: 1.0
# Testing Accuracy: 0.985
# Testing Confusion Matrix:
# [[ 27   0   0]
#  [  0   9   0]
#  [  3   0 161]]
# Testing Recall: 0.9939024390243901
# Testing Precesion: 0.9666666666666667
# Testing F1 score :0.9793792172739542
# ------------------------------
# Training Model XGB
# --------------
# [23:47:05] WARNING: ..\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
text_representation = tree.export_text(DT)
#print(text_representation)

# %%
model=DecisionTreeClassifier()
model = model.fit(x_train, y_train)
filename = "Diabetes_model.joblib"
joblib.dump(model, filename)
# Out:
# ['Diabetes_model.joblib']

# %%
# graph for decision tree

fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(model, feature_names=X.columns,class_names=['0','1','2'],filled=True)

fig.savefig("decistion_tree.png")

# %% [markdown]
# <a id='using Model'></a>
#
# ## using Model
#
#
# <a href="#content">back to content </a>

# %%
# create function 

def using_model():
    requirements=['age','hba1c','chol','bmi']
    dict_req={}
    predict_arry=[]
    for i in requirements :
        dict_req[i]=float(input(f"please enter your {i}"))
        predict_arry.append(dict_req[i])
    
    result=model.predict([predict_arry])
    
    answer=str(input("  please type \n 1- yes: to continue and get the result. \n 2- try: to try  correct your information again. \n 3- exit : to close the programe.  \n or enter the number of choices 1 or 2 or 3" ))
    print("*******************************************")
    if answer== "yes"or "Yes"or'1':
        if result==0:
            print("  it is good news for you, you don't have  diabetes  ^_^ ")
        elif result==1:
            print("  it is not good  news for you ,you  have  prediabetes .  you need to go to the doctor ")
        elif result==2:
            
            print(" I am sorry for you but  it is bad news ,you  have  diabetes ,  you need to go to the doctor fastly  ")

    elif answer=="try"or "Try"or'2':
        using_model()
     
    elif answer=="exit"or "Exit"or'3':
        print("Thanks for used my programe ^_^  ")
    else :
        print(" you entered  the wrong answer ")
        answer=str(input("  please type \n 1- yes: to continue and get the result.   \n 2- try: to try  correct your information again. \n 3- exit : to close the programe.  \n or enter the number of choices 1 or 2 or 3" ))
        print("*******************************************")

    return   result

# %%
using_model()
